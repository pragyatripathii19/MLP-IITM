# %% [markdown]
# You are required to manually disable these features in Colab by following the steps below:
#
# Steps to hide Generative AI features in Colab:
#
# - Open the shared Colab link using your student email ID.
#
# - In the top menu bar, click on **`Tools`**.
#
# - Select **`Settings`** from the dropdown menu.
#
# - Navigate to **`AI assistance`**.
#
# - Check the option **`Hide generative AI features.`**

# %% [markdown]
# ### $\color{red}{\textit{Important Note: This document is provided solely for viewing the questions.}}$
# $\color{red}{\textit{Please ensure that all answers are entered and submitted on the official exam portal.}}$

# %% [markdown]
# # Data PreProcessing

# %% [markdown]
# ### Q1 .Which dataset are you using for this exam? [0 Marks]
#
# Options:
#
# A) MLP_25T3_Preprocessing_V1
#
# B) MLP_25T3_Preprocessing_V2
#
# C) MLP_25T3_Preprocessing_V3

# %% [markdown]
# ### Q2.(NAT) [5 Marks]
# Compute the **Interquartile Range (IQR)** of the `Experience_Years` column in the dataset. (Enter correct answer upto 1 decimal)

# %% [markdown]
# ### Q3. (NAT) [5 Marks]
#
# Count the number of employees who satisfy **all** of the following conditions:
#
# 1. Belong to the **sales** department (case-insensitive).
# 2. Are **strictly older than 25 years**. (age > 25)
# 3. Do **not work remotely**.
#
# Report the total **number of employees** meeting these criteria.

# %% [markdown]
# ### Q4. (NAT) [5 Marks]
#
# Which pair of numerical features in the dataset has the **highest correlation**, and what is the **correlation value**?
# (Enter the correlation value up to 2 decimals)

# %% [markdown]
# ### Q5 (NAT) [5 Marks]
#
# Impute the missing values in the dataset as follows:
# - For **numerical columns**, replace missing values with their **mean**.
# - For **categorical columns**, replace missing values with their **mode**.
#
# After performing imputation, calculate the **new mean of the `Training_Score`** column. (Round to 2 decimals)

# %% [markdown]
# ### Q6 (NAT)  [5 Marks]
#
# For the column `department` in the dataframe:
# - Merge categories that have the **same name but different cases** (e.g., `tech` and `Tech` are considered same but have different cases).
# - After merging, perform **one-hot encoding** on the `department` column and transform the dataframe by replacing the original department column with the one hot encoded values.
#
# How many **columns** does the modified dataframe contain after this operation?

# %% [markdown]
# ### Q7. (NAT)  [5 Marks]
#
# Drop the `Employee_ID` column from the dataframe.
# Then, encode the `Remote_Work` column by replacing **"Yes" → 1** and **"No" → 0**.
# Now compute the difference between median age and medain experience years for this processed dataset.( Enter upto 2 decimals)

# %% [markdown]
# ### Q8. (NAT)  [5 Marks]
#
# Normalize the numerical features — `Work_Hours_Per_Week`, `Training_Score`, `Age`, `Experience_Years`, and `Projects_Handled` — using **Min-Max Scaling**.
#
# After normalization, compute the **ratio of the variance of `Age` to the variance of `Experience_Years`**. (Round to 2 decimals)

# %% [markdown]
# ### Q9. (NAT) [5 Marks]
#
# - Drop the Productivity_Score column before performing PCA.
#
# - Apply PCA with 3 components on the cleaned dataset (as per the steps mentioned in the previous questions).
#
# - Compute the percentage of variance explained by the first principal component.
#
# Enter your final answer as a percentage, rounded to two decimal places.

# %% [markdown]
# # Model building

# %% [markdown]
# ### Q1.Which dataset are you using for this exam? [0 Marks]
#
# Options:
#
# A) MLP_25T3_modelbuilding_V1
#
# B) MLP_25T3_modelbuilding_V2
#
# C) MLP_25T3_modelbuilding_V3

# %% [markdown]
# ### Q2. (NAT)  [5 Marks]
#
# We will now use this dataset for a **regression task**, where the **`Productivity_Score`** column will be treated as the label.
#
# - Separate the features and the label.
# - Split the data into **80% training set** and **20% test set**, using `random_state = 0`.
#
# Compute the **median normalized value of the `Age`** feature in the **test set**.

# %% [markdown]
# ### Common For Question 3 to 5:
#
#
# Train a **linear regression** model (with intercept) on the training dataset.

# %% [markdown]
# #### Q3. (NAT)  [5 Marks]
# Compute the **R² score** on the **training data**. (Round upto 2 decimals)

# %% [markdown]
# #### Q4. (NAT)  [5 Marks]
#
# For the same linear regression model, compute the **Root Mean Squared Error (RMSE)** on the **test set**.

# %% [markdown]
# #### Q5. (NAT)  [5 Marks]
#
# Find the **weight (coefficient)** of the **`Age`** feature given by the **Linear Regression model**.(Round to 2 decimals)

# %% [markdown]
# ### Q6. (NAT) [5 Marks]
#
# Perform **Lasso Regression** on the dataset using the following specifications:
#
# 1. Regularization parameter (`alpha`) = 0.1
# 2. Maximum iterations (`max_iter`) = 10000
# 3. Random state (`random_state`) = 0
#
# - Compute the **Ratio of Mean Squared Error (MSE) to Mean Absolute Error (MAE)** on the **test set**.
# - Round the final result to **2 decimal places**.

# %% [markdown]
# ### Q7. (MCQ) [5 Marks]
#
# Train a **Decision Tree Regressor** on the dataset using the following parameters:
#
# - Maximum Depth = 5
# - Minimum Samples Per Split = 10
# - Random State = 0
#
# **Which feature has been given the highest importance by the tree?**

# %% [markdown]
# ### Q8. (MCQ) [5 Marks]
#
# Perform **hyperparameter tuning** on a **DecisionTreeRegressor(random_state = 0)** using **GridSearchCV** with the following parameter grid:
#
# - Maximum Depth = [3, 5, 7]
# - Minimum Samples Per Split = [5, 10, 20]
# - Take cv = 5
# - Use **r2** as the scoring metric.
#
# After performing **GridSearchCV** on the Decision Tree Regressor, what is the **best combination** of `max_depth` and `min_samples_split`?
#
# - [ ] max_depth = 5, min_samples_split = 20
# - [ ] max_depth = 3, min_samples_split = 5
# - [ ] max_depth = 7, min_samples_split = 10
# - [ ] max_depth = 5, min_samples_split = 10

# %% [markdown]
# ### Q9. (NAT) [5 Marks]
#
# Train an **AdaBoost Regressor** (random state=0) with base estimator as a decision tree with random state=0 on the **training dataset**.
#
# - Compute the **Mean Absolute Error** on the **test set**. (Round upto 2 decimals)

# %% [markdown]
# ### Q10. (MCQ) [5 Marks]
#
# Perform **GridSearchCV** on the **AdaBoostRegressor(random_state=0)** using the following parameter grid:
# - Number of Estimators: [50, 100]
# - Learning Rate: [0.01, 0.1]
# - Use CV=5
# - negative mean squared error as scoring metric.
#
# **What is the optimal combination of learning rate and number of estimators?**
#
# - [ ] learning_rate = 0.1, n_estimators = 50
# - [ ] learning_rate = 0.1, n_estimators = 100
# - [ ] learning_rate = 0.01, n_estimators = 100
# - [ ] learning_rate = 0.01, n_estimators = 50

# %% [markdown]
# ### Q11. (MCQ) [5 Marks]
# You are required to train a **K-Nearest Neighbors (KNN)** Regressor on the given dataset.
#
# - Evaluate the model performance for k values in the range [3, 4, 5, 6, 7] using 5-fold cross-validation (CV = 5).
#
# - Use the **"r2"** as the scoring metric.
#
# Which value of k yields the highest average cross-validation score on the training dataset?
#
# - [ ] k = 3
# - [ ] k = 4
# - [ ] k = 5
# - [ ] k = 6
# - [ ] k = 7

# %% [markdown]
# ### Q12 (NAT) [10 Marks]
#
# You are required to train an **MLP Regressor** on the training dataset with the following specifications:
#
# - **Hidden Layers:** 3 layers with sizes `[64, 32, 16]`
# - **Activation Function:** ReLU
# - **Solver:** Adam
# - **Random State:** 0
# - **Maximum Iterations:** 1000
# Compute the **Root Mean Squared Error (RMSE)** on the **test set**. (Round to 2 decimals)
